# %%
import pandas as pd

# %%
parametros_fisicos = {
    # Rendimiento turbina-generador
    'eta':              0.85,
    'eta_ref':          'Paish (2002). Small hydro power. Renewable Energy. doi:10.1016/S0960-1481(01)00099-2. Rango 0.80-0.92 para Francis/Kaplan',

    # Horas operativas
    'horas_anio':       8760,
    'horas_ref':        'Constante física: 365 días × 24 horas',

    # Restricciones físicas del canal
    'dist_min_m':       500,
    'dist_min_ref':     'IDAE (2006). Minicentrales Hidroeléctricas. p.45. Longitud mínima viable canal',

    #Precio de venta de energía
    'precio_kwh':       0.08,
    'precio_kwh_ref':   'IDAE (2006). Minicentrales Hidroeléctricas. p.69. Precio venta 6.89 c€/kWh actualizado con IPC ×1.505',

    # Vida útil de la instalación
    'vida_util_anios':  25,
    'vida_util_ref':    'IDAE (2006). Minicentrales Hidroeléctricas. p.69. Tabla central tipo',

    # Parámetros de penalización del AG ─
    'pen_escala':       1000,
    'pen_ref':          'Parámetro interno del AG. Escala de penalización suave para soluciones inválidas',

    # Sobrecoste por curvatura del canal
    'eur_grado':        3200,
    'eur_grado_ref':    'PREOC (2024). Excavación en roca dura. Capítulo obras hidráulicas. Estimación sobrecoste por grado de curvatura',

    # Coste fijo de conexión a red
    'coste_conexion':   600_000,
    'coste_conexion_ref': 'REE (2024). Tarifas acceso MT zona rural Galicia. Estimación tipo tramo < 5 km',
}

df = pd.DataFrame([parametros_fisicos])
df.to_csv(
    '/content/drive/MyDrive/TFG - UAX/CSV/parametros_fisicos.csv',
    index=False, encoding='utf-8-sig'
)
print('Creado el csv correctamente => parametros_fisicos.csv generado')
 # Mostramos los valores
print(df.T)
# Out:
# Creado el csv correctamente => parametros_fisicos.csv generado
#                                                                     0
# eta                                                              0.85
# eta_ref             Paish (2002). Small hydro power. Renewable Ene...
# horas_anio                                                       8760
# horas_ref                       Constante física: 365 días × 24 horas
# dist_min_m                                                        500
# dist_min_ref        IDAE (2006). Minicentrales Hidroeléctricas. p....
# precio_kwh                                                       0.08
# precio_kwh_ref      IDAE (2006). Minicentrales Hidroeléctricas. p....
# vida_util_anios                                                    25
# vida_util_ref       IDAE (2006). Minicentrales Hidroeléctricas. p....
# pen_escala                                                       1000
# ...
